# %% [markdown]
# There are two keys aspects we are looking from reviews text
#
# - Key topics from set of reviews
# - apart from just key topics contextual similarity of these reviws and hence the key topics within same context
#
#
# the Attention Mechanism addresses the issue of emphasing of contextual importance of a word in different sentences.
#
# BERT is the first popular model comes to our mind thinking of above problems hence we will use the pre trained BERT model to extract meaningful topics as required and we shall do it in following key steps
#
# - Preprocess and clean the data using regex
# - get bert topics using pre trained Model
# - Extract top n keywords(2-3 grams)

# %%
# !pip install bertopic
# !pip install flair

# %%
import pandas as pd
import pickle
import time
import sys
import numpy as np
from functools import partial
from copy import deepcopy

# %%
pd.set_option('display.max_colwidth',100)
pd.set_option('display.max_rows',100)

# %%
target_data=pd.read_csv('Datafiniti_Amazon_Consumer_Reviews_of_Amazon_Products.csv')
target_data.head()
# Out:
#                      id             dateAdded           dateUpdated  \
# 0  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 1  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 2  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 3  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 4  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
#
#                                                     name       asins   brand  \
# 0  Amazon Kindle E-Reader 6" Wifi (8th Generation, 2016)  B00ZV9PXP2  Amazon
# 1  Amazon Kindle E-Reader 6" Wifi (8th Generation, 2016)  B00ZV9PXP2  Amazon
# 2  Amazon Kindle E-Reader 6" Wifi (8th Generation, 2016)  B00ZV9PXP2  Amazon
# 3  Amazon Kindle E-Reader 6" Wifi (8th Generation, 2016)  B00ZV9PXP2  Amazon
# 4  Amazon Kindle E-Reader 6" Wifi (8th Generation, 2016)  B00ZV9PXP2  Amazon
#
#                                                                                             categories  \
# 0  Computers,Electronics Features,Tablets,Electronics,iPad & Tablets,Kindle E-readers,iPad Accessor...
# 1  Computers,Electronics Features,Tablets,Electronics,iPad & Tablets,Kindle E-readers,iPad Accessor...
# 2  Computers,Electronics Features,Tablets,Electronics,iPad & Tablets,Kindle E-readers,iPad Accessor...
# 3  Computers,Electronics Features,Tablets,Electronics,iPad & Tablets,Kindle E-readers,iPad Accessor...
# 4  Computers,Electronics Features,Tablets,Electronics,iPad & Tablets,Kindle E-readers,iPad Accessor...
#
#   primaryCategories  \
# 0       Electronics
# 1       Electronics
# 2       Electronics
# 3       Electronics
# 4       Electronics
#
#                                                                                              imageURLs  \
# 0  https://pisces.bbystatic.com/image2/BestBuy_US/images/products/5442/5442403_sd.jpg,https://c1.ne...
# 1  https://pisces.bbystatic.com/image2/BestBuy_US/images/products/5442/5442403_sd.jpg,https://c1.ne...
# 2  https://pisces.bbystatic.com/image2/BestBuy_US/images/products/5442/5442403_sd.jpg,https://c1.ne...
# 3  https://pisces.bbystatic.com/image2/BestBuy_US/images/products/5442/5442403_sd.jpg,https://c1.ne...
# 4  https://pisces.bbystatic.com/image2/BestBuy_US/images/products/5442/5442403_sd.jpg,https://c1.ne...
#
#                                                                                                   keys  \
# 0  allnewkindleereaderblack6glarefreetouchscreendisplaywifiincludesspecialoffers/b00zv9pxp2,allnewk...
# 1  allnewkindleereaderblack6glarefreetouchscreendisplaywifiincludesspecialoffers/b00zv9pxp2,allnewk...
# 2  allnewkindleereaderblack6glarefreetouchscreendisplaywifiincludesspecialoffers/b00zv9pxp2,allnewk...
# 3  allnewkindleereaderblack6glarefreetouchscreendisplaywifiincludesspecialoffers/b00zv9pxp2,allnewk...
# 4  allnewkindleereaderblack6glarefreetouchscreendisplaywifiincludesspecialoffers/b00zv9pxp2,allnewk...
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#                                                                                       reviews.dateSeen  \
# 0                  2018-05-27T00:00:00Z,2017-09-18T00:00:00Z,2017-09-06T00:00:00Z,2017-09-12T00:00:00Z
# 1  2018-05-27T00:00:00Z,2017-07-07T00:00:00Z,2017-08-09T00:00:00Z,2017-08-02T00:00:00Z,2017-08-31T0...
# 2                                                                                 2018-05-27T00:00:00Z
# 3                                                                                 2018-10-09T00:00:00Z
# 4                                                                                 2018-05-27T00:00:00Z
#
#   reviews.doRecommend   reviews.id reviews.numHelpful reviews.rating  \
# 0               False          NaN                  0              3
# 1                True          NaN                  0              5
# 2                True          NaN                  0              4
# 3                True  177283626.0                  3              5
# 4                True          NaN                  0              5
#
#                                                                                     reviews.sourceURLs  \
# 0  http://reviews.bestbuy.com/3545/5442403/reviews.htm%25252525253Fformat%25252525253Dembedded,http...
# 1  http://reviews.bestbuy.com/3545/5442403/reviews.htm%25252525253Fformat%25252525253Dembedded%2525...
# 2  https://reviews.bestbuy.com/3545/5442403/reviews.htm%2525252525253Fformat%2525252525253Dembedded...
# 3  https://redsky.target.com/groot-domain-api/v1/reviews/51467832?sort=helpfulness_desc&limit=1000&...
# 4  https://reviews.bestbuy.com/3545/5442403/reviews.htm%2525252525253Fformat%2525252525253Dembedded...
#
#                                                                                           reviews.text  \
# 0  I thought it would be as big as small paper but turn out to be just like my palm. I think it is ...
# 1                                      This kindle is light and easy to use especially at the beach!!!
# 2  Didnt know how much i'd use a kindle so went for the lower end. im happy with it, even if its a ...
# 3  I am 100 happy with my purchase. I caught it on sale at a really good price. I am normally a rea...
# 4  Solid entry level Kindle. Great for kids. Gifted for a kid of my friend and they love to use it ...
#
#                                   reviews.title  reviews.username  \
# 0                                     Too small            llyyue
# 1  Great light reader. Easy to use at the beach            Charmi
# 2                           Great for the price      johnnyjojojo
# 3                                   A Great Buy           Kdperry
# 4      Solid entry-level Kindle. Great for kids       Johnnyblack
#
#                                                                                             sourceURLs
# 0  https://www.newegg.com/Product/Product.aspx%25253FItem%25253D9SIAFVD7FK6707,https://reviews.best...
# 1  https://www.newegg.com/Product/Product.aspx%25253FItem%25253D9SIAFVD7FK6707,https://reviews.best...
# 2  https://www.newegg.com/Product/Product.aspx%25253FItem%25253D9SIAFVD7FK6707,https://reviews.best...
# 3  https://www.newegg.com/Product/Product.aspx%25253FItem%25253D9SIAFVD7FK6707,https://reviews.best...
# 4  https://www.newegg.com/Product/Product.aspx%25253FItem%25253D9SIAFVD7FK6707,https://reviews.best...
#
# [5 rows x 24 columns]

# %%
# !pip install contractions
# Out:
# Requirement already satisfied: contractions in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (0.0.55)
# Requirement already satisfied: textsearch>=0.0.21 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from contractions) (0.0.21)
# Requirement already satisfied: pyahocorasick in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from textsearch>=0.0.21->contractions) (1.4.2)
# Requirement already satisfied: anyascii in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from textsearch>=0.0.21->contractions) (0.3.0)

# %%
import nltk
import re
import string
nltk.download('stopwords')
from nltk.corpus import stopwords
import contractions
stop_words=stopwords.words("english")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/ec2-user/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def clean_text(text):
    
    ## remove punctuation ###
    text=text.translate(string.punctuation)
    
    ## convert words to lower case and split them ###
    text=text.lower().split()
    
    ## remove stopwords
    stops=set(stopwords.words("english"))
    text=[w for w in text if not w in stops and len(w)>=3]
    
    text=" ".join(text)
    
    ### clean text
    
#     text=re.sub(r"[A-Za-z0-9^,!.\/+-=]"," ",text)
    text=re.sub(r"what's","what is",text)
    text=re.sub(r"\'s"," ",text)
    text=re.sub(r"\'ve","have",text)
    text=re.sub(r"i'm","i am",text)
    text=re.sub(r"n't","not",text)
    text=re.sub(r"\'re","are",text)
    text=re.sub(r"\'d","would",text)
    text=re.sub(r"\'ll","will",text)
    
    text=re.sub(r","," ",text)
    text=re.sub(r"\."," ",text)
    text=re.sub(r"!"," ! ",text)
    text=re.sub(r"\/"," ",text)
    text=re.sub(r"\^"," ",text)
    text=re.sub(r"\+"," ",text)
    text=re.sub(r"\-"," ",text)
    text=re.sub(r"\:"," ",text)
    text=re.sub(r"\;"," ",text)
    text=re.sub(r"''"," ",text)
    
    ## remove contractions
    
    text=contractions.fix(text)
    
    return text

# %%
text_d=target_data['reviews.text']

# %%
clean_text_d=[clean_text(x) for x in text_d]

# %%
from bertopic import BERTopic
from flair.embeddings import TransformerDocumentEmbeddings
from sentence_transformers import SentenceTransformer, util

# %%
clean_text_d
# Out:
# ['thought would big small paper turn like palm  think small read it    comfortable regular kindle  would definitely recommend paperwhite instead ',
#  'kindle light easy use especially beach !  !  ! ',
#  'did not know much iwould use kindle went lower end  happy it  even little dark',
#  '100 happy purchase  caught sale really good price  normally real book person  year old loves ripping pages  kindle prevents that  extremely portable (it fits better purse giant book)  loaded lots books  finish one start another  without store  serves needs  picked one paperwhite price unbeatable difference could see one backlit  simple book light dollar tree solves issue  second kindle (the first old keyboard model  put fell love keyboard  lol) likely last ',
#  'solid entry level kindle  great kids  gifted kid friend love use read ipads  battery good higher model bit better ',
#  'make excellent ebook reader  expect much device except read basic ebooks  good thing cheap good read sun ',
#  'ordered daughter  black paperwhite  love it  read quite bit larger books driving crazy hold laying down  wanting take book vacation lugging around thick paperback  throw bag read anywhere  light weight  easy use  battery life lasts weeks  makes around awesome device  daughter public school offer online library e readers  download books free school !  also download public library app (if county offers that) read free well  shop e books straight device amazon com ',
#  'bought kindle months ago battery already dead charge',
#  'amazon kindle always best ebook  upgrade every new model',
#  'beyond expectation  even show music score  fast turning though ',
#  'really want good read something digital item looking for  really lightweight highly functional  battery lasts long time screen easy eyes  difficulty sometimes reading extremely bright environments  overall excellent buy ',
#  'love kindle  makes reading night easy feels like reading real book ',
#  'good product child  need read books',
#  'kindle convenient size yet lettering easy read ',
#  'use every day commute  great battery life  backlight readable normal lighting  like built dictionary  email pdf mobi files easy transfers ',
#  'job would buy one screen brighter  times difficult read screen bright',
#  'great product myself !  bought great deal it ! ',
#  'item work well easy read day light',
#  'great product service refer friend  sales man good',
#  'everything great except canot read external pdfs properly  either zooms much little  kindle books provides great experience  battery life awesome ! ',
#  'looking kindle whitepaper  saw online $80  deal  ordered line picked store  got home adjust brightness  lengthy time online customer service called customer service  minuets speaking female elmer fud speak english well figured would return it  although looks identical $120 model  adjust brightness  would good information bought it ',
#  'nice bare bones reading device  easy set use  greatest issue back lit canot used w o light room  returning purchasing paperwhite instead ',
#  'easy use navigate  purchasing books fast simple love fact password protect device',
#  'amazon kindle light weight easy use ',
#  'love hear readers  replace mine destroyed last  awesome',
#  'love simplicity  also love use reading canot download distracting apps ',
#  'husband loves kindle  muscular disease keeping able handle anything much weight all  perfect ',
#  'ihave wanted kindle decided get put sale  disappointed ',
#  'several kindles knew expect  great reading device keep several different locations ',
#  'like reader  wish screen higher resolution  requires decent light look good  easy eyes  screen updates involve flashing whole screen  noticed less time  advertised month long battery life standby time  lasts much less downloading reading books ',
#  'fiancée really enjoyes it !  would definitely recommend ',
#  'simple  great buy money avid reader ',
#  'like changes made since current year old unit purchased',
#  'fits nicely hand touchable  increase size fonts',
#  'great buy  lot reading glear screen awesome sun ',
#  'lie size weight kindle makes convenient take large books digital format ',
#  'great price works great book reading  would recommend',
#  'got sale  totally fall love it  bring everywhere ',
#  'never used kindle before  wife gifted birthday  amazing product  using daily reading  display fantastic strain eyes ',
#  'bought paper white didn⊙t see much difference terms resolution use  totally recommend reader it⊙s small powerful ! ',
#  'sales people really nice knowledgeable come back',
#  'i am longtime kindle user jumped opportunity bring granddaughter fold gift  loved it ! ',
#  'overall good product  advertised  comfortable use ',
#  'kindle come handy lately  always book read great grab go  battery life great  drawback backlight ',
#  'loving new kindle !  wanted one finally bought one  even though cheapest one  exceeded expectations  love glare ',
#  'already older version kindle  one even better  love touch screen ability scroll without buttons ',
#  'bought 90  year old  totally no tech mom  first e book gone wind  likes size ease use ',
#  'amazon kindle products always reliable  consistent quality different  happy it ',
#  'working well cheap think price way',
#  'battery last long advertised  money would recommend backlit model ',
#  'kindle lighted screen like pricier models higher dpi screen lower model  exactly needed  nothing more  nothing less  ihave problems reader far iwill give stars ',
#  'kindle good download apps books catch reading',
#  'first one stopped working weeks best buy replaced fuss going great  small  lightweight (so fits purse handbag) anti glare screen read direct sunlight',
#  'bought kindle paperwhite son use school  instead expensive delicate tablet  display options make adaptable anyone  much easier eyes reading extended period time  please keep mind glowlight  kindle durable  although bought case it  case really is not necessary relatively careful it  surprising thing extra long battery life  son avid reader  noticed needs charge kindle considerably less uses tablet ',
#  'great item  easy use would recommend anybody want use ! ',
#  'bought gift dad loves it  well worth do not plan reading dark ',
#  'future reading like whole library',
#  'bought daughter  wanting get kindle without access games (like kindle fire)  latest version kindle excellent  jealous daughter thinking upgrading older kindle  touchscreen responsive  like reading kindle  worth update ',
#  'great way read books go  there  backlight  reading darker rooms may hard  affordable portable great way take books you ',
#  'love kindle  great product  reduces eye strain enjoy reading it  second kindle ',
#  'bought backup  currently using headphone ',
#  'got kindle daughter accompanied try two kindle models  willing buy either one assumed would want expensive one backlighting feature  tried both  gravitated certainty toward basic model  "why would want read dark?" said  weeks months gone by  says completely happy basic kindle  exactly wanted  perfect ',
#  'good  able read bright sunlight conditions',
#  'easy handle  many books choose convenient',
#  'purchased product love read buying books got costly  product read want 10 00 month',
#  'smaller thought gets job done ',
#  'love new kindle !  read hesitant kindle  easy use  lightweight convenient pick book  great outdoor reading  downside want read dark back light  crisp clear text easy set up ',
#  'product good  light  amazing battery backup  charge kindle one weeks  great product reasonable price  usb connection easy  books easy download  overall  everyone must kindle best product model start with understandably  beginner level model people never used kindle before  features like led lights  white paper background available model  features higher models one cannot read dark without lights  again  price would get good readers if someone reads dark would suggest higher kindle models ',
#  "kindle perfect e reader  easy use size perfect bring 'book' go ",
#  'easy use arrived exactly described  good beginner device youngsters want device read from ',
#  'looking picture seeing 8th generation assumed would great device  original kindle stopped using backlit  thought 8th generation would backlit picture makes look backlit not  minutes phone amazon trying make brighter technician finally realized 8th generation supported backlights  took back target purchased paperwhite money definitely worth it  8th generation one smaller assumed reason price difference  target made experience pleasant ',
#  'fiance really enjoyes it !  would definitely recommend ',
#  'me  kindle black good fit me  times read night bed husband sleeping  model back light i am unable read night without turning light waking husband so returned went kindle fire ',
#  'still best device buying books reading them  however  kindle paperwhite read books dark places ',
#  'great product service sales man really nice ',
#  'first turn kindle  home screen make easy determine exactly open read downloaded book ',
#  'wife loves it  replaces kindle like 2003 ',
#  'small  light  easy read from  wish would spent extra bucks got paperwhite  use one wish option backlight  fence was  paperwhite !  however backlight issue  device great would recommend it ',
#  'device good entry level reader daylight its doesnot support reading dark  read dark purchase light cover case light attached  either case put lot strain eyes ',
#  'love new kindle  size perfect  fits right purse  easy navigate love touch screen  able read outside without glare  flaw backlit  order read dark need book light  mind much  wish kindle would come case kindle built book light like first generation kindle ',
#  'would load books proper  took dozen tries erasing dreregistering  screen dark',
#  'bought daughter  4th kindle bought within family  touchscreen great daughter loves it  fact  older model kindles jealous ',
#  'pretty cool little device  able download books wireless read later convenience  drawback wish storage  price  works good ',
#  'exactly looking size wise functional ',
#  'always  great job !  easy use always me  problem button bottom touchy  really issue  keep good work',
#  'especially like amazon system convert pdf kindle format  things read (journal articles) pdf format email kindle email shows kindle kindle format (larger text)  find kindel email account information  thing  would like screen little larger ',
#  'happy it  comfortable easy use every',
#  'eighth kindle  others either lost screen damaged  bought spare  current model better looking earlier versions (white case)  sturdier  improved screen  great price also  wish iwould bought two ',
#  'nephew going college next year want give gift  kindle suits well learn study ',
#  'excellent lightweight way take lot reading materials along traveling ',
#  'love kindle !  i am back reading much often always several books times !  first surprised version back light need light read  actually like get eye strain like using phone ',
#  'love real books  great travel keeping bookshelves lighter  wish could buy larger storage without buy larger size pad  also sucks 4gig  1gig taken advertising  seriously? reads pdfs needs gig os  lame  last thing would change able reverse lettering night could white lettering black background  less bright eyes ',
#  'perfect gift young adult holiday session ',
#  'screen dark  cannot adjust brightness',
#  'purchased kindle sooner  easy use love it ! ',
#  'purchased gift theyhave absolutely loved it ',
#  'great gift anyone  easy setup  coexist iot devices  alexa awesome ! ',
#  'super excited give gift  super convenient best buy echo products store instead purchase amazon ',
#  'bought mother law  buying another me ',
#  'well designed  good sound  everything alexa plus video  always ready answers associated video text applicable  show movie trailers  also watch amazon video  excellent on demand security video amazon compatible cameras  voice activated message and or video calls amazon show owners alexa app holders  highly recommended ',
#  'one alexa three echo dots echo show awesome ! ',
#  'omg love amazon show sooo cool lot cool stuff',
#  'great looking design  amazon echo show easy set use ',
#  'product entertaining useful  would recommend anyone ',
#  'got weeks kind fades away life ',
#  'device awesome ⊘ really let us get excited smart home technology ⊘ i⊙m buying second one upstairs',
#  'purchased daughter tell happy hugged box back box ! ',
#  'overall product excellent  speakers capability used bluetooth speakers like echo ',
#  'spot  dot two shows  started spot loved much wanted bigger one  (best buy) pun intended lol',
#  'little hesitant spend money get glad did !  alexa always answers say commands noticed probably 95% right command given  love fact see things screen  news briefings picture video that  nice too  also love video call option  planning getting one grandma technologically advanced  could sit table talk grandkids  worth every penny ',
#  'great product  much recommended  service best buy always best',
#  'bought gifts  love echo think new one incredible too !  holidays  buy one myself ! ',
#  'watch videos  check security cameras  grey two fantastic price',
#  'dreams need topics  song lyrics scroll song play  watch movies trailers etc  it  get sale  bought special deal best buy $129 99  sure value regular price of$249 99  cool device ',
#  'information weather  updates music  events  fun questions answered working kitchen  good sound limited areagreat sales assistance best buy',
#  'bought christmas present son family communicate visually ',
#  'amazon echo excellent  easy set up  use automate entire house air conditioning thermostat every light house phillips hue bulbs  went got one everyone family ',
#  'amazon echo amazon show prefer show video screen  use show display recipes cooking  lyrics music i⊙m listening video conferencing family  like seeing headlines stories scroll across screen along t8me temperature ',
#  'using amazon echo show couple days works great  microphone picks voice easily  sound quality great  looks nice sitting coffee table ! ',
#  'echo show let us see much  great item home ! ',
#  'echo easy use features allow users converse easily others may hard time learning communicate using newer videophone technology  product removes barriers ',
#  'love echo show wish could watch movies shows tube hopefully add soon ',
#  'love echo products one exceptional well  able look house away  waiting update access apps future ',
#  'little putsy far  continuous updates think make great device stay connected family  bought second dad  knows  might replace land line someday gets better  think original echo bit better responding  enjoy one kitchen  aka hub house ',
#  'heart echo  screen it  1000s things make much easier recommendation simarly priced screenless echo plus',
#  'amazon echo show best amazon products  love hands free able see things screen ',
#  'house work great bought christmas gifts family',
#  'love alexa !  love able watch news briefings  seeing lyrics songs  much more !  kitchen use everyday ! ',
#  'unit good job playing music amazon music  hears voice good although gets confused times tell turn particular lamp slowly pronunciate it  like music shows lyrics  need family account amazon music plan different music different units different rooms time though ',
#  'it⊙s awesome able control lighting lots controls this ! ',
#  'i⊙m big echo fan  seemed like brainer  like lot  i⊙m disappointed google pulling youtube functionality  also feel like original echo speaker sounded little better listened better kitchen related background noise ',
#  'jealous son showed amazon show things capable doing  since aol eliminated instant messaging  wife less able communicate offices separate floors  got two shows two spots intercom easily use alexa music many things  probably start using smart home devices alexa also control  fun device seems getting better time ',
#  'use monitor amazon cloud camera !  works great tell show camera  and boom  there⊙s video feed  super easy link echo plus echo dot show !  ! ',
#  'use echo almost every day  fun ask questions  music great  check weather listen nprnews',
#  'love playing music talking alexa looking camera three screen',
#  'love echo show 3rd one purchased (two presents family christmas)  one me  love able hear music  connect family via video ask alexa questions  best purchase could made ! ',
#  'awesome sound unexpected  nice seeing info screen recipes  song lyrics  weather  etc ',
#  'love capability see screen allows use hands ',
#  'screen really nice great videos would definetly recommend',
#  'bought two for deal presents  mother learning curve  since one going son  teach her !  looks like neat appliance  want see weather  music turning lights   ',
#  'far favorite amazon product  bought one every bedroom home ',
#  'fun music ready voice command  use amazon unlimited nearly everything  good view recipes allrecipes  keep kitchen reference musical ambience  video good too  youtube functionality  would nice regular though  probably providers now   nice photo background lastly  lyrics screen music played ! ',
#  'using original echo seldomly  decided get show    use show lot more  simple set make calls video  great product',
#  'say little confusing frustrating getting verification code amazon waited minutes requested another code  nothing    nother one    still nothing started set device 8 30 11 20 fed it   step away     hours went shopping mall recieved codes amazon     ',
#  'dad uses speaker    and loves it  use traditional alexa way   but speaker option discovered added benefit ',
#  'alexa runs entire house  echo show great addition echo family  everyone needs one ! ',
#  'replaced regular echo unit  allows video chat son college replaces digital picture frame affordable price ',
#  'love echo show  best feature flash bringing gives rundown news weather morning ',
#  'girlfriend loves echo show  bought two them   ',
#  'along fire tv  prime membership  amazon music subscription  home automation devices alexa app phone system functional ',
#  'it⊙s alexa  screen  sounds pretty decent countertop device  wife loves kitchen recipes  weather music fun ! ',
#  'purchased present friend since echo video chat check in  quality video great ',
#  'like another person house  talk alexa wife',
#  'really love use everyday works great',
#  'struggled surprise christmas gift year  store sales rep suggested hit ! ',
#  'echo show game changer  amazing echo  one watch video   see who  door  things echo limitless  like personal assistant ',
#  'another great product amazon  super fun great entertaining family guests ',
#  'great product fun use  easy set begin useing',
#  'gift relative said loved gift ',
#  'echo screen adds appeal product ',
#  'purchased buying echo dot daughter thought would fun family  play music every day it  every one family enjoying it  dislike doesn⊙t hub ',
#  'live echo show !  easy set use  one kitchen one main bathroom ',
#  'alexa may new  would thought simple commands would able respond already  amount amazon charges  come better instructions  including specifically download one  device (iphone  etc ) make apps ready go  amazon dropped ball one ',
#  'previously owned nucleus device similar device great device lot bugs much returned it  device masterpiece !  tied alexa echo universe  used intercom throughout house echos also used view things even call people echo directly  amazing piece hardware amazon proud developing beautiful device ! ',
#  'love echo show kitchen use almost daily listen music cook also find new recipes try  kids use help homework  whole family uses ease everyone loves it ',
#  'love took place echo bedroom ',
#  'fantastic product exactly described  great gift idea ! ',
#  'really like call someone facetime them ! ',
#  'bought gift parents absolutely love it ! ',
#  'love even four year old tell alexa "call papa" alexa turn kitchen lights ! ',
#  'find saying phone  "alexa  play         "  wish made car too ',
#  'love echo show integrates smart house devices cameras  use view cameras  listen music  make phone calls video calls even recipe guide cooking  i⊙ve impressed ! ',
#  'going lie haven⊙t even opened yet  planning getting setup tomorrow night  see store though incredible',
#  'like screen able see things like weather reports  etc  still using full potential  controlling couple lamps  giving weather reports  setting timers alarms  making lazy !  sometimes hear voice  hears husband  voice better  find best put pretty close side table ',
#  'love this  replaced old echo one  love alexa ',
#  'recently purchased amazon show  easy setup use also added specialty screens home screen  extremely glad bought it ',
#  'enjoy asking questions history educational stuff kids ',
#  'love echo show  elexa helpfull answers every question',
#  'echo dot  great video calling intercom calling house  use every day  run photo⊙s stored amazon prime music ',
#  'treat !  what⊙s weather forecast? what⊙s news morning?? need know plus smart home control !  ! ',
#  'purchased children separated miles  canot wait open gifts',
#  'amazon echo show great addition connected home  allows link phillips hue nest systems control voice  great display available information awesome ',
#  'worked advertised easy set link wi fi ',
#  'love able get visual effect along audio alexa',
#  'think worth sale price $150 00 limitations  example shows calendar see first item  ask more  see next so  screen updating trivia   some interesting much  bet next generation lot better',
#  'everyone product  it⊙s great needing see something hands full can⊙t find phone ',
#  'first read amazon echo show  thought sound quality would inferior echo small size  would deal breaker  read sound actually superior echo compatible existing security cameras  decided buy one  best buy ran strong promotion buy caved bought number echo  echo dots house)  completely blown away echo show !  !  brief summary thoughts  likes  substantially best sound quality echo date  stronger bass  directional stereo  dolby audio focused sound field front  rock louder  less sound sides back  share music all  echo 2  far field microphones effective echo  high resolution screen perfect desk kitchen  song lyrics great !  (free optional setting turn lyrics)  photos album cover band music awesome !  buttons top  mute camera defeat red screen indicator  volume volume down  excellent resolution built in camera  auto presence detector turns show screen detected  speak alexa  echo dot  show mutes volume shows asked screen  music volume lowered background  10  ask forecast get written verbal forecast  also get second screen showing next days  including real feel  picture anticipated weather  chance rain  etc  11  say  alexa  show "front porch"  numerous security cameras within seconds  highly detailed live video sound !  12  video conference know anyone else show yet  cannot try call see picture see adjust surroundings  13  uses power supply amazon echo  14  sleek shape fits right contemporary surroundings (see photo show center desk monitors ipad pro)  15  touch screen sensitivity perfect  16  build quality first rate !  17  rubber feet protect surface anti slip  18  addictive !  device  one want center desk  shown photo  add video component  wonder enjoyed music  sports  everything  without it !  19  see shopping list  20  see visual confirmation lights ask alexa turn actually turned on  dislikes  none !  would offer one design option  would offer optional amazon echo show wireless subwoofer beast  could buy later  would work like many soundbars include wireless sub  would allow show rock out  shake walls time ! i seriously planning sell echos dots pick couple shows  great !  ! ',
#  'actually gift  second one purchased great priduct',
#  'i⊙ve asked itquestions answers unknown could help',
#  'great product  easy use  very easy set',
#  'product great nice addition echo family ',
#  'connects echo dot bluetooth ease  works great',
#  'love echo  use everyday  one thing  claims pick voice anywhere room  that  always case  big deal  get little closer louder follows request answers question  love it ! ',
#  'nice add work arlo pro cams like sing karaoke alexa',
#  'first concerned funny looking angle saw pictures  item displayed local store decided take chance  owner echo dot figured would work manner does  love works arlo pro  screen great soon figured reason funny angle item  angled screen works great setback recommendation would add auxiliary output rear  also watch prime movies  youtube videos etc ',
#  'bought white version kitchen  use everything  music  video  phone  security cams  news  weather  perfect kitchen assistant ',
#  'alexa best one due screen feature',
#  'love everything alexa    you⊙re fence   buy it   everything !  !  ! ',
#  'like amazon echo echo dot love best part make list listen music puts words screen',
#  'time searching replacement sony dash support discontinued recently  sure bedside "smart" alarm clock primary goal echo show fit bill nicely  first echo purchase multiple echo  hue lights  great system around ! ',
#  'alexa  better younger sister  love her  new skills great',
#  'show good picture good sound   love using look things',
#  'awesome product  first echo product owned purchased get $100 off  going split friend like much decided keep both  ihave singing along stream song lyrics work kitchen house watching youtube videos  videos youtube takes effort find ones want think improve time ',
#  'echo show comes handy  use almost much thought would  still learning do  favorite part screen  it⊙s huge deal  could change one thing would detachable power cable instead hardwired ',
#  'it⊙s good  google smart  answers one asks  kind spooky  distinction voice context absent',
#  'like ease usage amazon show  amazon echo decided upgrade video call  overall great product ! ',
#  'transforming house smart home  far thus favorite  much learn day',
#  'visuals entice utilizing product greater frequency  easy set works well  manual accompany product  going online encourages purchase book directions  rather simple online manual ',
#  'enjoy getting recipes news via alexa  great speakers ',
#  'bought echo seeing demonstrated brother  proceeded ask alexa questions alexa would answer immediately  asked pull songs which  right away  asked call mom well  needless say  get one ',
#  'like video feature doorbell  wish automatically showed picture door bell rung  facetime  maybe later  also cameras compatible ',
#  'problems far i am enjoying it  suggestion come outputs plugs connect bigger speakers sound system',
#  'love control whole house lighting phillips hue bulbs  well everyday use alarms  reminders  questions  news even adjusting a c  pandora music playlists  bought one family well ',
#  'first echo product echo dots  step us  placed kitchen love it !  sound outstanding love screen feature  buying additional ones family well myself ',
#  'love new echo show the best alexa family',
#  'almost week late release date ups finally got set easy  hear right that  probably due feet away problems',
#  'item purchased gift annual holiday party  recipient loved it ',
#  'starting smart home addition already dot echo  simple set kids even control it !  ! ',
#  'bought view arlo pro cameras something iphones  show great job this  fantastic alexa device  minor complaints slightly smaller expected can⊙t view youtube videos it  huge deals all  minutely disappointing ',
#  'awesome sound amazing  screen outstanding',
#  'neat item  fun talk to  easy set use ',
#  'play trivia family learn lot world',
#  'love it⊙s second alexa it⊙s conceted everything house thinking buying',
#  'ease use comparability smart home products make awesome product',
#  'i⊙ve amazon alexa since first hit streets two years ago echo show awesome !  much alexa echo dot !  love it ! ',
#  'favorite house  even visitors love it  amazing ! ',
#  'purchased mom memory care center  doesn⊙t answer phone  simply drop start talking sees us  picture clarity awesome !  staff also aware camera feature knows drop frequently  doesn⊙t replace room camera good  would give can⊙t figure alexa owners drop her  anyone know?',
#  'great product  absolute love it  alexa fun converse wealth information',
#  'love see answer screen alexa echo show !  !  ! ',
#  'bit involved getting set thereafter function simply talking alexia  plug adapter turn lights useful certainly worth having ',
#  'adds nice tricks regular echo lineup  video calls show owners works well  speakers sound good ',
#  'echo show works well  time cannot connect youtube  maybe amazon wakes connection returned ',
#  'lot fun  fully enjoy it  get amazon music unlimited  bought four them  keep touch family  alexa entertaining ! ',
#  'seen one son in law enjoyed using it ',
#  'love see grandkids  also bought kids one "drop in" see them  also shows words songs sing along  fun have !  ! ',
#  'best product used ai  easy set easy use ',
#  'you⊙re lik trying update home smart home  must need  bed side able see front door',
#  'echo show great  use monitor outside inside cameras ',
#  'alexa show technology tablet except voice activated',
#  'wonderful  bought boyfriend get use',
#  'amazon show great addition smart home  easy set link hub ',
#  'echo show great plug play  app directions understandable problems  however  amazon hot line helpful  but  wants call help every week two keep things running  alexa able talk resolve issues  getting used features like it ',
#  'best assistant amazon  completion screen also see images cameras devices ! simply awesome ! ',
#  'satisfied purchase  see family without tango  skype etc   different phones ios android see it⊙s clear thanks amazon      ',
#  'echo show works well bluetooth wifi  great sound screen  recommend anyone',
#  'works great !  dogs would actually answer call would even better !  they⊙re interested least see they⊙re',
#  'love addition echo show alexa devices  screen read recipes viiew notes great ! ',
#  'looking something help keep organized keep date weather  markets  latest news amazon echo show looking for  honestly  product top line technology  easy use long patient work it  read directions  size truly perfect  honestly reminds size normal alarm clock would nightstand  truly serve purpose  also touch screen  feel durable stand last  sound quality also superb  dual 2 inch speakers  bluetooth capabilities well  works android  samsung  fire os  ios device  excluding mac products  echo show comes two colors black white  product many different features functions  accommodate pretty much anyone⊙s needs  top feature alexa app  application call commands ask questions anything  believe music capabilities truly amazing ask play almost song playlist whenever want  also tell volume well  another new modernized technology capability hands free voice command smart home options  couple things could improved  sometimes fully hear exact words  search something aren⊙t expecting  function could could single voice recognition several voices  don⊙t entire room trying mess constantly  price also fair well  creative capabilities has  trying find new technology add home echo show would great addition you ',
#  'love echo show much !  easy use  connects mobil phone easily call people ! ',
#  '9 5 10 rating one best products used while  screen smart home device useful  really canot compete google home show brings convenience without call it  primarily use show turn on off smart lights  simple cooking measurements  simple math  travel time  store location hours  calling  video calling     more  everything else like  news  calendars  weather already displayed screen  definitely worth plan using minimum features above ',
#  'love many features highly recommend it !  using echo saves lots unnecessary work    that⊙s amazing ! ',
#  'used home office  gives information ask computers chores  plays music request  decent quality sound ',
#  'like show  canot say love it  priciest piece collection alexa devices  probably worst microphone  getting respond frustrating times  problem standard echo  besides this  works advertised  iwould wait second generation  i am sure work kinks out ',
#  'bought gift  far know works fine',
#  'great sound amazing options  love this !  !  !  great replacement original echo',
#  'bought gift gotten use much yet  initial setup really easy sure going love it ! ',
#  'facilitates easy home set up many smart devices ',
#  'amazon echos pick add rooms  work best bedroom kitchen  video display bright  video calling great addition flawlessly  get sale',
#  'multiple echos dots one way better  doesn⊙t like seeing lyrics music  using video chat echo shows  two thinking getting another one soon ',
#  'user friendly  hand free little assistant  makes mornings easier gets started day  looks cool',
#  'bought sister christmas  loved them ! ',
#  'love it   easy use  many different features   ',
#  'echo show awesome product alexa itself !  answer questions ask her  play music demand  even ask make calls video chats you  also like fact sounds nice video quality unlike anything ihave ever seen hybrid tablet product  must home ! ',
#  'works well sounds good pictures good',
#  'bought echo show display disappointed  echo purchased somebody gift purchased working great  thing disappointed bluetooth play music itunes  display also vivid clear ',
#  'purchased device launch pack $384 xx) youtube work  youtube one main features used  without youtube better buying $40 echo dot instead ',
#  'i⊙m love alexa  love fir music  quick weather updates kitchen recipes  it⊙s great getting step step keep putting passcode ipad hands covered flour ',
#  'amazon  echo show great help daily rutine  asking simple things like weather specific things like flash briefings traffic commute  echo show great tool tech enthusiast',
#  'children loving alexa always talking alexa every day hehehe',
#  'alexa great product perform tasks answer kinds questions  show video feature makes much interactive ',
#  'use office personal assistant  home',
#  'alexa controls lights  sound system  happy this ',
#  'bought two kids  love echo dot',
#  'love amazon echo show !  video display helpful  good quality video audio sounds better echo plus speaker  search recipe use without flipping recipe books  need know measurement conversion? ask alexa !  learn cooking techniques  recommended cooking times   endless list available answers  great addition kitchen  love play christmas music throughout home using echo devices  lots fun  works like echo products    with smart accessories control home thermostat  lights etc  alot expandable options ',
#  'love new pad  new kitchenalso bought alexa pods family xmas',
#  'average alexa option  show things screen still limited ',
#  'got spur moment thing  figured going super gimmicky pleasantly surprised actually helpful device organizing  shopping  smart home control  listening music  even watching videos i am washing dishes  show kitchen ihave used countless things  think amazon  best alexa yet ',
#  'gave husband birthday loves it !  able change screen picture phone different pictures everyday  nice tell alexa keep track need store  can⊙t wait use more ! ',
#  'love echo  alexa awesome    christmas present    also received two dots place rooms    ',
#  'bought start implementing smart home features  gets job done screen nice addition ',
#  'keep asking things  surprised much',
#  'bought christmas gift  actually seen action yet  checked reviews good  best buy awesome black friday price ',
#  'show one alexa enabled machine  love words songs i am able watch amazon prime videos ',
#  'fun easy use  music sounds great  set timers  reminders sync calendar  i am giving one gift daughter video chat "drop in" time ',
#  'plug play  easy use  speakers good music ',
#  'love thing !  it⊙s fun easy use  year old even uses play trolls lion king soundtrack',
#  'echo show great addition amazon family  works like echo  screen  bright vibrant display  rich clear sound  works great arlo security cameras  excellent smart home addition  hope google amazon start playing nice soon youtube work again ',
#  'purchased capstone team test review would benefit today  journalist ',
#  'product super easy use sound quality terrific  use every day !  easy use also appreciated ! ',
#  'fairly easy use set use  annoying issue kids try talk her  mainly use music general information ',
#  'like alexa stuff connect phone  plan getting door bell video stuff next ',
#  'amazon echo show excellent add on video features  screen smaller expected meet requirements ',
#  'stars bing  works great arlo cameras',
#  'display great video calls others echo show  works well home automation devices  sound great listening music ',
#  'bought alexa show whim  great decision  wife daughter absolutely love it  ask alexa questions play favorite music time  display nice  love sleek look it  amazon outdone itself ',
#  'daughter bought show year old grandson could get touch got home school bought one could call see other  love it ',
#  'great addition amazon device family  great christmas gift ',
#  'purchased amazon echo show alexa store  took home connection wi fi great  cannot wait buy light bulbs thermostat  great buy',
#  'sure expect echo show  super happy bought it  alexa great  tells weather  traffic  news updates day ',
#  'great looking recipes cooking hands tied up  also  perfect ⊜dropping in⊝ family friends ',
#  'already amazon devices echo  dot )  expected device slightly different amazon device screen  pleasantly surprised large number helpful features screen could bring  occasionally scrolls suggestions across screen  helpful  i am planning setting another one year old mothers house  shewill get kick also ',
#  'bought christmas family members i⊙ve mine year kitchen love it ! so much works great arlo pro cameras big plus   amazon always updating show more ',
#  'despite less friendly price point (if get sale)  amazon item well designed delivers promises hype product description  emphasis item "show"  surprise sound quality compare echo  want convenience voice controlled screen phone  product delivers  value even greater paired smart devices security cams  another added bonus comes friends family also show  "drop in"  essentially visual phone calls  great checking elderly family require technically savvy ',
#  'previously echo dots play home  knew wanted alexa  echo show kitchen allows easy review youtube entertainment recipe instructions  also like streaming music lyrics stream  too !  !  !  cool  looking forward alexa learning respond questions various topics  hands free way go ',
#  'alexa show purchased replace another much older device show good device lacking aspects older device  i am sure i am missing show able get internet cameras older device (such san diego zoo elephants) canot get show  certainly deal breaker fun watch  setup pretty straight forward easy  good aspect talk device knows want certain extent  literal times make sure exact code words get something want  (such "play" "start" "open") use alarm clock quite easy set time week would little difficult work one weekend day week combination  would set several different alarms  one day far see  alarm sound choices bit alarming  really want terrified awake day  found one mellow moderate sound level works well  would nice able add alarm sounds could customized like  see yet anywhere  another thing alarm try dismiss touch screen wrong way puts alarm snooze mode instead turning off  tell dismiss alarm works fine times iwould rather say anything time day dismiss swipe  possible  sensitive miss  comes snooze !  little things may get fixed future enough feedback customers may effect people much people impact particular anomaly  thinking getting thermostat hooks monitor change heat cooling future time  hoping works well arrives it nice raise temp degree cold winter without get warmth bed  iwould say good emerging technology needs little work  considering type thing science fiction long ago kind weare heading ',
#  "alexa show really well put together  main reason purchase create  urveillance system' linking ring doorbell  ring floodlights view command alexa show screen  yes  talk it  get results almost query  show  get lot more  touch screen great video calls  especially install alexa app family cell phones  alexa scan items via upc order amazon  tell get them  recipes ask spoken you  shown you  also  music plays  see lyrics screen (if use amazon music play music)  ask news briefing  see news  highlights  etc  speakers quite standard echo series  close  sound fills room nicely  echo show immediately used  screen shows picture choice  making digital frame too  overall  device nice  constantly releasing new skills alexa use  seems like always something new wow you  turning lights  adjusting thermostat  playing music  viewing security cameras standard duties  way device ! ",
#  'resisted getting since already two echo units one dot  black friday gave reason buy one  love twice much regular echo  set faster easier love visuals  use shopping list list lot display able edit without logging app makes much worth it  may getting another',
#  'real upgrades iphone learning curve sure  however camera better plus ',
#  'greatly enjoyed using alexa gadget kitchen ',
#  'love echo show  personal assistant  dj  weatherman news person one  second show  love video qualties sound canot beat ',
#  'entire family enjoyed purchases store',
#  'wife wanted gift disappoint  next step amazon  capabilities  adding visual sound already there ',
#  'alexa  thought show would cool would allow link camera it  see videos info wanted look up  play prime video account  would could see prime shows movies it ',
#  'echo show works great home automation  able see security cameras drop home echos camera great features ',
#  'great  needs expanding information it ',
#  'echo (still do  another room) purchased show  also couple dots set communicate other  walk show  gives mini tips  news  fun facts  etc  love it !  even use like skype others show ',
#  'wife wanted this  got gift  even though amazon echo year  think show much better  screen takes lot mystery alexa doing  wife daughter love it ',
#  'thing awesome  great speakers too  grab one',
#  '5th echo show  love drop feature  allowing use intercom  ease playing music throughout house  controlled device used daily  connection sonos system real plus  also connected dish receiver ',
#  'love echo show many features  great purchase ',
#  'use communicate family  love drop feature it⊙s much easier hear everyone opposed facetime speakerphone  offer  enough recommend anyone uses video keep touch ',
#  'recommended me  love it  use music  timer kitchen  great recipes  love question day  weeks can⊙t wait explore more ! ',
#  'bought daughters dorm  good device streaming  making calls  etc   even quick weather report',
#  'love much !  using every day   news  youtube videos    buying smart home products make good use alexa ',
#  'love unit  well designed built  easy use huge amount features  screen beautiful  audio could use bit bass imho  bought christmas gifts ',
#  'screen really add tremendous value  bugs almost worked quality hearing commands night day month ago ',
#  'really enjoy echo show !  echo living room echo show bedroom  it⊙s great visual requests alexa',
#  'love it  bought one everyone family   know they⊙ll love',
#  'purchased year old mother safety convenience  entertainment device  loves it !  finds easy use  loves music throughout house ',
#  'amazon made another great product !  ⊜show⊝ goes perfectly kitchen !  recipes  music weather !  done hands free !  !  fast set up ! ',
#  'bought gift adult kids video chat college  second best feature youtube  amazon sell google home chromcast goodness sakes ! ',
#  'another great echo product    really cool feature lyrics scrolling across screen playing music ! ',
#  'works fast clear  speakers sound amazing  looks great bedroom ',
#  'several versions amazon  echos original  echo plus  taps dots  show best sounding bunch screen bonus  added battery pack make portable perfect us ',
#  'love it  much easy use  use mostly music questions ',
#  'love echo show  found many uses weather updates  recipes random questions  grandkids love stories  songs  pictures plain silly  think ihave tapped full potential yet  think person wrong purchase ',
#  'fun useful  interactive still learning abilities ',
#  'it⊙s great use lot yes tell friends family',
#  'really like it⊙s user friendly coolidge apple family family',
#  'lot fun using kitchen  think use much thought would ',
#  'alexa reminds appointments it⊙s great tool',
#  'nice way see internet also view security cameras  handy device ',
#  'easy log set up  good sound  needs remote volume changes radio station  song  replies ',
#  'alexa awesome screen makes even better canot wait get another',
#  'thanks display version alexa love model ',
#  'must great recepies  cooking alexa gives info  ines used tablet ipod stop read awesome plus  much easier follow things ',
#  'love alexa everything do !  great connect devices ',
#  'bought echo show mom birthday loves it !  use time ',
#  'lot echos devices  room house kind smart speaker also google home devices) the echo show best device use living room kitchen  screen bright sharp  nice feature follow recipes  watch videos even listen music lyrics displayed screen it  also best way see calendar entries  shopping lists ',
#  "love show  easy set up  use every day music weather info  can'y wait see works christmas cookies ",
#  'learning amazon echo show do  ihave used timer  ihave listened iheart radio  love smart lights bought time  alexa turns on off tell to  holiday rush over  online learn many things ',
#  'thing really cool  love gives words songs',
#  'i⊙m amazon prime member show awsum use communicate son lives seattle  watch amazon pirime tv play amazon music  text  play games read lyrics song playing  love',
#  'one favorite gadgets   any things ',
#  'easy set up  simple use  lots fun !  alexa tell weather forecast  play music you⊙d like hear  read recipes much more !  great product',
#  'responsive program  limited information program  user friendly ',
#  'best item ever use  would love get another one ',
#  'alexa lot fun things must enable various apps  gives funny answers funny question  however  complete internet surfer  many things answer ',
#  'bought son laws birthday bought one christmas  good music helpful grandkids homework video chat grandkids  one year old loves ! ',
#  'using kitchen  whole family access use different functionality  great looking recipies  music calling relatives friends',
#  'got work arlo pro camera  works well  able camera driveway front door come command  hate cannot get samsung come verbal request  guess buy plug it  easy set up  downloaded app  plugged in  viola walks setup ',
#  'waited couple months review giving amazon time make product equal sony dash nearly decade ago  screen provides nothing value canot turn amazon tips !  near zero customization canot even move clock side screen  something sony dash nearly years ago pandora prime music alarm !  seriously biggest fail !  run away half baked amazon disaster ! ',
#  'impressed it  monitory arlo cameras ever want treat sirius radio',
#  'easy use good quality  nice picture good size desk',
#  'alexa device great fun  useful several personal assistant type applications  use conjunction tp link light switches  works flawlessly  nice see lyrics songs plays  calling people show spot works well  also really good setting reminders alarms  another useful feature home intercom ',
#  'love even turn talk alex tell her ',
#  'great help assistants store  knowledgeable took time help choose right product needs ',
#  'nice see calendar sound good too ',
#  'great product  cost  speakers be  screen small  choosing desplayed screen something still figired out  hopefully software updates fix minor problem  second generation hopefully fix hardware downfalls  voice recognition also good eco dot  recomending product time cost poor performance ',
# ...
#  'i⊙m amazon prime member show awsum use communicate son lives seattle  watch amazon pirime tv play amazon music  text  play games read lyrics song playing  love',
#  'loved echo dot  show exponentially better  especially love see words songs played  views places world want see  big difference cost dot show  worth it ! ',
#  'love new echo show  many features echo dot ',
#  'looking product while  much research  bought disappointed  great product  tell bored learning echo show do  thinking buying it  it ',
#  'amazon show great addition smart home  easy set link hub ',
#  'like pictures weather screen news dates',
#  'everything amazon  even see front door arlo !  netflix  hulu  that  okay  really like sound  fills small rooms  easy video chat nana  drop tell kid  goodnight  working late ',
#  'facilitates easy home set up many smart devices ',
#  'really enjoyed products much actually bought them  fun watch even better amazon prime customer music video ',
#  'great electronic easy install family enjoy things alexa satisfied service received best buy purchase looking forward shopping often i am new customer',
#  'show nice features audio quality isn⊙t best price point  got mine sale using bedroom alarm clock  read time without glasses i still use sonos play listen sleep playlist music  unless missed something seems like set volume low night listen music sleep alarm loud enough  don⊙t use show music much ',
#  'setting amazon show little tricky but managed navigate it  it⊙s cool add compatible equipment ',
#  'great video calling grandparents real tech savvy  also enjoy music demand ',
#  'requires many components  cameras  etc  stick basics (in opinion) ',
#  'loving far !  bought great deal able use previous best buy awards get cheap  also ended buying another one parents christmas chat back forth !  love echo  connect home ',
#  'happy echo show  able listen christmas songs country western music  many things wait try some ',
#  'purchased item  unaware much really does  literally control entire home it ',
#  'echo show everything thought would more  alarm music actions greatest ',
#  'wanted see would work super accurate  kind fun',
#  'alexa video version recipes more  love it ! ',
#  'normally like kind stuff  honest alexa great  use fun stuff like music cooking  able multi task much easier  fit seamlessly home security system  added extra cam  really add something extra home',
#  'video integration big plus video calling kids home quick check who  door doorbell rings ',
#  'show good picture good sound   love using look things',
#  'bought gift  far know works fine',
#  'unit good job playing music amazon music  hears voice good although gets confused times tell turn particular lamp slowly pronunciate it  like music shows lyrics  need family account amazon music plan different music different units different rooms time though ',
#  'reservations purchase echo show  quickly eroded setting using since christmas day  everyone family loves camera function  sound quality  picture resolution basically everything it ! it totally perfected yet work progress comes skills choose use device since definitely designed amazon customers  versatile enough everyone could find something enjoy music  pictures  videos favorite book read you  one favorite features ole time radio series offered skills  takes back time relax similar good book  preference offer much new skills daily added  although several echo dots everywhere  6yo loves come echo show hear music see new pictures uploaded cloud  sound amazing size  that  huge plus  pictures dynamic far issue anyway shape  slightly odd seems blend decor pretty well  hopefully newer even better skills made real gem rough tons applications still ahead used for  connected home security system  robot vacuum cleaner times cell phone  taken together useful  fun nice addition gadget loaded home ',
#  'added screen great features visual effect plus',
#  'use echo almost every day  fun ask questions  music great  check weather listen nprnews',
#  'picked show black friday deal  probably would never paid full price  glad show  actually quite useful  sound quality also better standard echo  moment  complaints lack youtube support price   interesting see features amazon add show future ',
#  'awesome product  first echo product owned purchased get $100 off  going split friend like much decided keep both  ihave singing along stream song lyrics work kitchen house watching youtube videos  videos youtube takes effort find ones want think improve time ',
#  'love amazon echo devices  right allow youtube  hopefully reach agreement fix that ',
#  "love show  easy set up  use every day music weather info  can'y wait see works christmas cookies ",
#  'totally addicted easy use  love call feature ',
#  'sales associate knowledgeable enough lead right direction purchasing product that⊙s compatible mother⊙s arlo security cameras  works great ! ',
#  'first thing noticed alexa⊙s response time questions  waiting downloading lightning quick responses  2nd compatibility smart hone features  connects lights security monitoring system ease  clear concise ',
#  'product great  easy use easy set',
#  'helpful addition home  great able set timers  play music  check news hands free ',
#  'alexa make crazy it⊙s worth aggravation ',
#  'things echos screen  sound comparable echo good  screen small  hd  touch screen  call echo users if echo run buy laptop  looking echo screen might worth extra bucks ',
#  'upgraded echo needed  works well new ring door bell security cameras  love versatility this ',
#  'alexa great even better screen show searches videos',
#  'first bought dot see liked it  enjoyed it  wanted little volume  saw show much louder camera decided right choice  dot bedroom show living room  larger rooms show great choice ',
#  'great product recommend friends family ',
#  'hesitant  hooked  fun useful',
#  'show sounds significantly better echo plus  added screen features nice  wish ⊜things try section⊝ would away',
#  'amazon echo user friendly  provides hours entertainment  anything recipes  news  videos  amazon music lyrics like karaoke ',
#  'great product many functions would highly recommend friend ',
#  'device must studied practiced gain max use robust capacity',
#  'bought echo show get hyped benefits alexa  home automation  using week  decided return echo show  alexa ready prime time  90% time got canot answer that" response questions  waste money us  say "alexa  say good bye ! "',
#  'product ties amazon ecosystem better dot echo  provides better sound quality plays video  pairing nest cameras best  quick easy  highly recommend product ',
#  "alexa all !  severe hearing loss   how' gives visuals along captions follow alexa saying ! ",
#  'echo show video screen nice upgrade echo⊙s  news briefs videos nice  good sound quality playing music ',
#  'one need like dot  echo ihome one screen',
#  'great instantly see family members chat  demonstrate  check in    plus wonderful features echo devices including video clips  movies  etc',
#  'amaizin like way type search favorites',
#  'quickly become one used kitchen counter !  alexa like it  must upgrade ',
#  'second show  and  one several christmas gifts  convenient fun !  easy set up  use alexa devices whole house intercom listening music ',
#  'use alexa every day  know lived',
#  'purchased amazon echo show alexa store  took home connection wi fi great  cannot wait buy light bulbs thermostat  great buy',
#  'exactly wanted do  easy voice commands ',
#  'love new echo show the best alexa family',
#  'bought eco show replace first gen eco (the original tube)  show hears understands lot better ',
#  'love alexa show  answer questions use recipes listening music  use everyday ',
#  'screen great upgrade  music lyrics displayed good quality speakers  convenient recipes make hands free calls great audio quality  great product ! ',
#  'bought echo show friend mine excited his  i am hoping makes great christmas present family ',
#  'bought white version kitchen  use everything  music  video  phone  security cams  news  weather  perfect kitchen assistant ',
#  'buy  ! the video adds great value songs  news  etc also  accessing videos netflix adds greatly ',
#  'echo show feels useless hours  especially without ability watch youtube ',
#  'device especially useful know others it  offers features standard echo  along expanded feature set well ',
#  'entire family loves product  ask questions sleep playing music  feel like company anytime want',
#  'must great recepies  cooking alexa gives info  ines used tablet ipod stop read awesome plus  much easier follow things ',
#  'got two days holidays  good service',
#  'amazon echo show best amazon products  love hands free able see things screen ',
#  'love thing !  it⊙s fun easy use  year old even uses play trolls lion king soundtrack',
#  'love kitchen  play music  ask questions  make list  set timers  etc ',
#  'overall works well  sound better dot  screen clear ',
#  '9the screen show much thought would works great speaker seems good it ',
#  'haven⊙t used yet  gift father think he⊙ll love it ',
#  'dot first gen echo sound show way better echoes  video functions nice pain get play videos amazon library  family enjoys calendar info news briefings rotate screen ',
#  'video calls work great screen super informative ',
#  'resisted getting since already two echo units one dot  black friday gave reason buy one  love twice much regular echo  set faster easier love visuals  use shopping list list lot display able edit without logging app makes much worth it  may getting another',
#  'easy set use  really like screen view items searched for  read information searched item ',
#  'recommended good practice  play music good quality speaker see video  love',
#  'love playing music talking alexa looking camera three screen',
#  'product sure come handy  easy use  precise accurate and knowledgeable ',
#  'average alexa option  show things screen still limited ',
#  'amazon show one best smart home devices every came out  alexa  videos  music  drop in  amazing product !  !  ! ',
#  'echo previously  screen opens options alexa  find helpful able glance screen see things like time weather  also cameras setup use alexa view feeds  unit kind large  stable supports touch  tried video calling playing videos  screen quality seems pretty good ',
#  'best new adult toy years !  wish purchased one parents  love it !  !  !  ! ',
#  'multiple echoes like show best  screen adds lot value opinion  really like able see upcoming calendar events daily news  kids like watching cartoons amazon prime eating breakfast  speakers great put enough quality sound size  $149 great deal ',
#  'bought several alexa⊙s christmas gifts also also bought amazon show christmas gift also youngest daugter',
#  'one best   i dots nice cameras ask camera get screen   spend extra',
#  'wife said i⊙m developing ⊜star trek⊝ home   while i⊙m still learning regular echo  looking forward getting ring doorbell installed !  great product  rave enough them !  !  ! ',
#  'lazy mans drean combined alexa  get harmony hub really impress home automation',
#  'really enjoy fire stick  really easy use ',
#  'really cool device !  instantly noticed difference quality switched regular fire stick fire 4k ',
#  'love it !  works great  one main rooms ',
#  'works great  turns h&a down  off  lights off  alexa  apps special lights ',
#  'love alexa echo device (and smart bulb) much bought echos bulbs come soon   ',
#  'went store  purchased gifted it snap ',
#  'love convenience able turn light appliances connected smart switches voice commands  also convenient music streaming  news weather reports ',
#  'replaced old echo one smart hub  works great',
#  'nice hub use lights plugs  sometimes echo work ',
#  'speaker used giveaway everyone wanted it !  huge hit conference  would buy again ',
#  'bought moms birthday loves it ',
#  'like smart machine recommend friends',
#  'purchased product sale  easy pair  looks well made  happy it ',
#  'love it  it⊙s lot fun  great speakers provides lot great information fun too ! ',
#  'really enjoying device far   my smart phone basic tracfone   currently adding smart lighting   will probably switch tablet controlling adding future (limited) smart home',
#  'great item  love echo  could mow yard kids    ',
#  'alexa walks every step found helpful ',
#  'sonos speakers honeywell lyric thermostat  took little searching google get things linked  linked play music room change home temperature using alexa ',
#  'i am techie  days trying hook up  gave up  know echo plus carrier att uverse causing issue  would connect  so  back store went  even checking blogs internet assistance   none worked ',
#  'alexa amazin  love features great just love',
#  'speaker truly amazing able control lights makes even better',
#  'new echo plus fun find  working advertised  still exploring many  many ways use device  need tech savvy apps  wifi  willingness reading various "skills" well worth it  already added echo dot mix ',
#  'love knowledge gives  easy older brother does  technology ',
#  'enjoy amazon alexa  lot fun  helpful completely set up  ',
#  'i⊙ve enjoy echo since purchased light bulbs great buying products',
#  'wanted one awhile finally got one  works great  way better siri iphone  speaker works great music  happy overal',
#  'items easy set up  added value home ',
#  'works great !  bought kitchen master bath ',
#  'definitely recommend product tech support also easy friendly  alexa keeps husband company day answering questions ',
#  'originally purchased use bluetooth speaker wife  music soon realized would use much thought  ya  turning lights good able dim included bulb pretty great hundreds smart home type apps work including sony google show regularly  makes almost easy lazy ',
#  'pretty fun little gadget  kids love playing it  even sure things yet',
#  'extremely satisfied purchase new toy ! ',
#  'bought devices kids    report simple start up  easy use fun ! ',
#  'ultimate lazy life happening eyes  love technology always let⊙s honest telling alexa turn lights ask tell joke examples really great i⊙m addicted hue line well ',
#  'alexa ricks plus best ever buy love',
#  'yet explore aspects  enjoy using daily ',
#  'fun talk alexa  sound also high quality  happy purchase ',
#  'one favorite purchases  easy set up  already works dish hope directv gets soon ',
#  'saw product used friends impressed  bought one husband christmas ',
#  'love able turn light walk inside hands !  alexa lifesaver',
#  'far used alexa play music  comment would wish larger variety opera music ',
#  'bought present wife  relaxed holiday requested six hours different song play  wife enjoyed music music emanated open areas house  wife received information measures recipes  weather updates  etc  one classic gifts ',
#  'echo nice could better allowing connect anything wifi network without buy several different hubs ',
#  'need buy additional parts it⊙s great',
#  'enjoyed learning home automation using echo plus consumers need know comes buy additional equipment get alexa ',
#  'love product !  love everything it !  !  ! ',
#  'two dots functionality awesome  can⊙t wait see improves time  great quality speaker build ',
#  'really enjoy echo use control lights music house',
#  'wife loves alexa  uses pandora kids love talking it ',
#  'love alexa although sometimes hard time understanding find repeating commands ⊜alexa turn lights bedroom⊝ overall she⊙s amazing tells jokes date current events',
#  'several  one christmas gift daughter  love convenience creating lists home automation  get started  come things use for ',
#  'great way introduce family friends a i  technology ',
#  'third alexa combined fire lights couch time increased  love new technology !  ! ',
#  'amazing piece technology  impressed sound quality',
#  'bought family everyone loves it !  definitely recommend buying one ! ',
#  'gave gift kids christmas  enjoying alexa ',
#  'present mother  fun !  loves looking things easier talk out ',
#  'alexa amazing phillips bulb works seamlessly it ',
#  ...]

# %%
embedder=SentenceTransformer('bert-base-nli-stsb-mean-tokens')
# Out:
# Downloading:   0%|          | 0.00/391 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.98k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/630 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/229 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/409 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
bert_model=BERTopic(embedding_model=embedder,language='english',verbose=True,calculate_probabilities=True)

b_topics, bprobs=bert_model.fit_transform(documents=clean_text_d)
# Out:
# Batches:   0%|          | 0/157 [00:00<?, ?it/s]
# 2021-11-17 03:36:33,140 - BERTopic - Transformed documents to Embeddings
# 2021-11-17 03:37:12,256 - BERTopic - Reduced dimensionality with UMAP
# 2021-11-17 03:37:14,115 - BERTopic - Clustered UMAP embeddings with HDBSCAN

# %%
target_data['topic_id']=b_topics
target_data.head()
# Out:
#                      id             dateAdded           dateUpdated  \
# 0  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 1  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 2  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 3  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 4  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
#
#                                                     name       asins   brand  \
# 0  Amazon Kindle E-Reader 6" Wifi (8th Generation, 2016)  B00ZV9PXP2  Amazon
# 1  Amazon Kindle E-Reader 6" Wifi (8th Generation, 2016)  B00ZV9PXP2  Amazon
# 2  Amazon Kindle E-Reader 6" Wifi (8th Generation, 2016)  B00ZV9PXP2  Amazon
# 3  Amazon Kindle E-Reader 6" Wifi (8th Generation, 2016)  B00ZV9PXP2  Amazon
# 4  Amazon Kindle E-Reader 6" Wifi (8th Generation, 2016)  B00ZV9PXP2  Amazon
#
#                                                                                             categories  \
# 0  Computers,Electronics Features,Tablets,Electronics,iPad & Tablets,Kindle E-readers,iPad Accessor...
# 1  Computers,Electronics Features,Tablets,Electronics,iPad & Tablets,Kindle E-readers,iPad Accessor...
# 2  Computers,Electronics Features,Tablets,Electronics,iPad & Tablets,Kindle E-readers,iPad Accessor...
# 3  Computers,Electronics Features,Tablets,Electronics,iPad & Tablets,Kindle E-readers,iPad Accessor...
# 4  Computers,Electronics Features,Tablets,Electronics,iPad & Tablets,Kindle E-readers,iPad Accessor...
#
#   primaryCategories  \
# 0       Electronics
# 1       Electronics
# 2       Electronics
# 3       Electronics
# 4       Electronics
#
#                                                                                              imageURLs  \
# 0  https://pisces.bbystatic.com/image2/BestBuy_US/images/products/5442/5442403_sd.jpg,https://c1.ne...
# 1  https://pisces.bbystatic.com/image2/BestBuy_US/images/products/5442/5442403_sd.jpg,https://c1.ne...
# 2  https://pisces.bbystatic.com/image2/BestBuy_US/images/products/5442/5442403_sd.jpg,https://c1.ne...
# 3  https://pisces.bbystatic.com/image2/BestBuy_US/images/products/5442/5442403_sd.jpg,https://c1.ne...
# 4  https://pisces.bbystatic.com/image2/BestBuy_US/images/products/5442/5442403_sd.jpg,https://c1.ne...
#
#                                                                                                   keys  \
# 0  allnewkindleereaderblack6glarefreetouchscreendisplaywifiincludesspecialoffers/b00zv9pxp2,allnewk...
# 1  allnewkindleereaderblack6glarefreetouchscreendisplaywifiincludesspecialoffers/b00zv9pxp2,allnewk...
# 2  allnewkindleereaderblack6glarefreetouchscreendisplaywifiincludesspecialoffers/b00zv9pxp2,allnewk...
# 3  allnewkindleereaderblack6glarefreetouchscreendisplaywifiincludesspecialoffers/b00zv9pxp2,allnewk...
# 4  allnewkindleereaderblack6glarefreetouchscreendisplaywifiincludesspecialoffers/b00zv9pxp2,allnewk...
#
#    ... reviews.doRecommend   reviews.id reviews.numHelpful reviews.rating  \
# 0  ...               False          NaN                  0              3
# 1  ...                True          NaN                  0              5
# 2  ...                True          NaN                  0              4
# 3  ...                True  177283626.0                  3              5
# 4  ...                True          NaN                  0              5
#
#                                                                                     reviews.sourceURLs  \
# 0  http://reviews.bestbuy.com/3545/5442403/reviews.htm%25252525253Fformat%25252525253Dembedded,http...
# 1  http://reviews.bestbuy.com/3545/5442403/reviews.htm%25252525253Fformat%25252525253Dembedded%2525...
# 2  https://reviews.bestbuy.com/3545/5442403/reviews.htm%2525252525253Fformat%2525252525253Dembedded...
# 3  https://redsky.target.com/groot-domain-api/v1/reviews/51467832?sort=helpfulness_desc&limit=1000&...
# 4  https://reviews.bestbuy.com/3545/5442403/reviews.htm%2525252525253Fformat%2525252525253Dembedded...
#
#                                                                                           reviews.text  \
# 0  I thought it would be as big as small paper but turn out to be just like my palm. I think it is ...
# 1                                      This kindle is light and easy to use especially at the beach!!!
# 2  Didnt know how much i'd use a kindle so went for the lower end. im happy with it, even if its a ...
# 3  I am 100 happy with my purchase. I caught it on sale at a really good price. I am normally a rea...
# 4  Solid entry level Kindle. Great for kids. Gifted for a kid of my friend and they love to use it ...
#
#                                   reviews.title  reviews.username  \
# 0                                     Too small            llyyue
# 1  Great light reader. Easy to use at the beach            Charmi
# 2                           Great for the price      johnnyjojojo
# 3                                   A Great Buy           Kdperry
# 4      Solid entry-level Kindle. Great for kids       Johnnyblack
#
#                                                                                             sourceURLs  \
# 0  https://www.newegg.com/Product/Product.aspx%25253FItem%25253D9SIAFVD7FK6707,https://reviews.best...
# 1  https://www.newegg.com/Product/Product.aspx%25253FItem%25253D9SIAFVD7FK6707,https://reviews.best...
# 2  https://www.newegg.com/Product/Product.aspx%25253FItem%25253D9SIAFVD7FK6707,https://reviews.best...
# 3  https://www.newegg.com/Product/Product.aspx%25253FItem%25253D9SIAFVD7FK6707,https://reviews.best...
# 4  https://www.newegg.com/Product/Product.aspx%25253FItem%25253D9SIAFVD7FK6707,https://reviews.best...
#
#   topic_id
# 0       68
# 1       13
# 2       -1
# 3       67
# 4       -1
#
# [5 rows x 25 columns]

# %%
target_data_68=target_data[target_data['topic_id']==68]
target_data_68.head()
# Out:
#                         id             dateAdded           dateUpdated  \
# 0     AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 39    AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 77    AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 1629  AVqVGZSEQMlgsOJE6eUc  2017-03-03T16:56:06Z  2018-09-21T18:45:21Z
# 1919  AVqVGZSEQMlgsOJE6eUc  2017-03-03T16:56:06Z  2018-09-21T18:45:21Z
#
#                                                                                             name  \
# 0                                          Amazon Kindle E-Reader 6" Wifi (8th Generation, 2016)
# 39                                         Amazon Kindle E-Reader 6" Wifi (8th Generation, 2016)
# 77                                         Amazon Kindle E-Reader 6" Wifi (8th Generation, 2016)
# 1629  Kindle E-reader - White, 6 Glare-Free Touchscreen Display, Wi-Fi - Includes Special Offers
# 1919  Kindle E-reader - White, 6 Glare-Free Touchscreen Display, Wi-Fi - Includes Special Offers
#
#            asins   brand  \
# 0     B00ZV9PXP2  Amazon
# 39    B00ZV9PXP2  Amazon
# 77    B00ZV9PXP2  Amazon
# 1629  B017JG41PC  Amazon
# 1919  B017JG41PC  Amazon
#
#                                                                                                categories  \
# 0     Computers,Electronics Features,Tablets,Electronics,iPad & Tablets,Kindle E-readers,iPad Accessor...
# 39    Computers,Electronics Features,Tablets,Electronics,iPad & Tablets,Kindle E-readers,iPad Accessor...
# 77    Computers,Electronics Features,Tablets,Electronics,iPad & Tablets,Kindle E-readers,iPad Accessor...
# 1629  Office,eBook Readers,Electronics Features,Walmart for Business,Tablets,Electronics,Amazon Ereade...
# 1919  Office,eBook Readers,Electronics Features,Walmart for Business,Tablets,Electronics,Amazon Ereade...
#
#                 primaryCategories  \
# 0                     Electronics
# 39                    Electronics
# 77                    Electronics
# 1629  Office Supplies,Electronics
# 1919  Office Supplies,Electronics
#
#                                                                                                 imageURLs  \
# 0     https://pisces.bbystatic.com/image2/BestBuy_US/images/products/5442/5442403_sd.jpg,https://c1.ne...
# 39    https://pisces.bbystatic.com/image2/BestBuy_US/images/products/5442/5442403_sd.jpg,https://c1.ne...
# 77    https://pisces.bbystatic.com/image2/BestBuy_US/images/products/5442/5442403_sd.jpg,https://c1.ne...
# 1629  https://www.barcodable.com/images/barcode/0841667100418.png,https://i5.walmartimages.com/asr/7b8...
# 1919  https://www.barcodable.com/images/barcode/0841667100418.png,https://i5.walmartimages.com/asr/7b8...
#
#                                                                                                      keys  \
# 0     allnewkindleereaderblack6glarefreetouchscreendisplaywifiincludesspecialoffers/b00zv9pxp2,allnewk...
# 39    allnewkindleereaderblack6glarefreetouchscreendisplaywifiincludesspecialoffers/b00zv9pxp2,allnewk...
# 77    allnewkindleereaderblack6glarefreetouchscreendisplaywifiincludesspecialoffers/b00zv9pxp2,allnewk...
# 1629  841667100418,0841667100418,amazonkindlewhite/5435001,amazon/53004447,kindleereaderwhite6glarefre...
# 1919  841667100418,0841667100418,amazonkindlewhite/5435001,amazon/53004447,kindleereaderwhite6glarefre...
#
#       ... reviews.doRecommend   reviews.id reviews.numHelpful reviews.rating  \
# 0     ...               False          NaN                  0              3
# 39    ...                True          NaN                  0              5
# 77    ...               False  152240083.0                  0              4
# 1629  ...                True          NaN                  0              4
# 1919  ...               False          NaN                  0              3
#
#                                                                                        reviews.sourceURLs  \
# 0     http://reviews.bestbuy.com/3545/5442403/reviews.htm%25252525253Fformat%25252525253Dembedded,http...
# 39    https://reviews.bestbuy.com/3545/5442403/reviews.htm%25252525253Fformat%25252525253Dembedded%252...
# 77    https://redsky.target.com/groot-domain-api/v1/reviews/51467832?sort=helpfulness_desc&limit=1000&...
# 1629         https://reviews.bestbuy.com/3545/5435001/reviews.htm%253Fformat%253Dembedded%2526page%253D19
# 1919  https://reviews.bestbuy.com/3545/5435001/reviews.htm%253Fformat%253Dembedded%2526page%253D30,htt...
#
#                                                                                              reviews.text  \
# 0     I thought it would be as big as small paper but turn out to be just like my palm. I think it is ...
# 39    I bought this with paper white and didn’t see much of a difference in terms of resolution and ...
# 77    It's small, light, and easy to read from. I just wish I would have spent the extra 30 bucks and ...
# 1629  Easy to figure out and I like the paperwhite because it doesn’t strain your eyes and you can a...
# 1919  This was my second kindle and I didn't realize that it wasn't paper white . What a difference. I...
#
#                       reviews.title  reviews.username  \
# 0                         Too small            llyyue
# 39                        Excellent           Faithfy
# 77    Should have bought paperwhite             Jessa
# 1629   Easy on the eyes, and to use            TeaKae
# 1919                        No like          nest1819
#
#                                                                                                sourceURLs  \
# 0     https://www.newegg.com/Product/Product.aspx%25253FItem%25253D9SIAFVD7FK6707,https://reviews.best...
# 39    https://www.newegg.com/Product/Product.aspx%25253FItem%25253D9SIAFVD7FK6707,https://reviews.best...
# 77    https://www.newegg.com/Product/Product.aspx%25253FItem%25253D9SIAFVD7FK6707,https://reviews.best...
# 1629  https://reviews.bestbuy.com/3545/5435001/reviews.htm%253Fformat%253Dembedded%2526page%253D40,htt...
# 1919  https://reviews.bestbuy.com/3545/5435001/reviews.htm%253Fformat%253Dembedded%2526page%253D40,htt...
#
#      topic_id
# 0          68
# 39         68
# 77         68
# 1629       68
# 1919       68
#
# [5 rows x 25 columns]

# %%
target_data=target_data.rename(columns = {'reviews.text': 'reviews'})

# %%
targ_df = pd.DataFrame(target_data, columns=["reviews"])
targ_df['Topic'] = b_topics
targ_df['Doc_ID'] = range(len(targ_df))
docs_per_topic = targ_df.groupby(['Topic'], as_index = False).agg({'reviews': ' '.join})

# %%
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer

def c_tf_idf(documents, m, ngram_range=(2, 3)):
    count = CountVectorizer(ngram_range=ngram_range, stop_words="english").fit(documents)
    t = count.transform(documents).toarray()
    w = t.sum(axis=1)
    tf = np.divide(t.T, w)
    sum_t = t.sum(axis=0)
    idf = np.log(np.divide(m, sum_t)).reshape(-1, 1)
    tf_idf = np.multiply(tf, idf)

    return tf_idf, count
  
tf_idf, count = c_tf_idf(docs_per_topic.reviews.values, m=len(target_data))

# %%
def extract_top_n_words_per_topic(tf_idf, count, docs_per_topic, n=20):
    words = count.get_feature_names()
    labels = list(docs_per_topic.Topic)
    tf_idf_transposed = tf_idf.T
    indices = tf_idf_transposed.argsort()[:, -n:]
    top_n_words = {label: [(words[j], tf_idf_transposed[i][j]) for j in indices[i]][::-1] for i, label in enumerate(labels)}
    return top_n_words

# %%
def extract_topic_sizes(df):
    topic_sizes = (df.groupby(['Topic'])
                     .reviews
                     .count()
                     .reset_index()
                     .rename({"Topic": "Topic", "reviews": "Size"}, axis='columns')
                     .sort_values("Size", ascending=False))
    return topic_sizes

# %%
top_n_words = extract_top_n_words_per_topic(tf_idf, count, docs_per_topic, n=5)
topic_sizes = extract_topic_sizes(targ_df); topic_sizes.head(10)
# Out:
#     Topic  Size
# 0      -1  1957
# 14     13   323
# 30     29   215
# 41     40   196
# 40     39   172
# 32     31   131
# 24     23   112
# 11     10   104
# 71     70    96
# 10      9    89

# %%
top_n_words[-1][1][0]
# Out:
# 'easy use'

# %%
def tuple_to_words(tup):
    out=[]
    for i in range(len(tup)):
        
        txt=tup[i][0]
        out.append(txt)
    return out

# %%
tuple_to_words(top_n_words[-1])
# Out:
# ['year old', 'easy use', 'best buy', 'battery life', 'works great']

# %%
review_topic_keywords=target_data[['reviews','topic_id']]
key_words=[tuple_to_words(top_n_words[x]) for x in review_topic_keywords['topic_id']]
review_topic_keywords['keywords']=key_words
review_topic_keywords.head()
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                                                                                reviews  \
# 0  I thought it would be as big as small paper but turn out to be just like my palm. I think it is ...
# 1                                      This kindle is light and easy to use especially at the beach!!!
# 2  Didnt know how much i'd use a kindle so went for the lower end. im happy with it, even if its a ...
# 3  I am 100 happy with my purchase. I caught it on sale at a really good price. I am normally a rea...
# 4  Solid entry level Kindle. Great for kids. Gifted for a kid of my friend and they love to use it ...
#
#    topic_id  \
# 0        68
# 1        13
# 2        -1
# 3        67
# 4        -1
#
#                                                                               keywords
# 0              [page turn, turn buttons, page turn buttons, kindle voyage, turn pages]
# 1                       [battery life, easy use, kindle love, old kindle, love kindle]
# 2                            [year old, easy use, best buy, battery life, works great]
# 3  [buy larger, real book, download books, thousands books hated, change able reverse]
# 4                            [year old, easy use, best buy, battery life, works great]
